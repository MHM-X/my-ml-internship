# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Refresh / Content Opportunity Scoring

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Research Question:** Which pages should be refreshed first to maximize potential traffic gains?
#
# **Decision:** Decide which pages should be updated first.
#
# **Action:** The content team updates the highest-priority pages before the others.
#
# **Cost of a Wrong Recommendation:** If the recommendation is incorrect, the team may spend time updating low-impact pages while high-impact pages continue losing traffic.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Dataset shape:")
print(df.shape)

print("\nTrend direction distribution:")
print(df["trend_direction"].value_counts())

print("\nAverage trend percentage:")
print(df["trend_pct"].mean())

# %% [markdown]
# The starter dataset contains 30,000 content pages with 44 available features.
#
# The data shows that 16,262 pages have a declining trend, while 5,962 pages are stable and 4,388 pages are increasing. The average trend change across the dataset is -4.79%.
#
# These numbers suggest that a significant number of pages are experiencing performance changes, creating an opportunity to prioritize which pages should be reviewed and refreshed first.
#
# This supports the Refresh / Content Opportunity Scoring lane because a data-driven ranking approach can help the content team focus limited time and resources on pages with higher potential impact instead of manually reviewing all pages.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# The work will be able to identify patterns in observed content performance signals and create a ranked list of pages that may deserve review or refresh attention.
#
# The output will be decision-support: it can help the content team prioritize pages based on available evidence, but it will not guarantee that a page will recover after being updated.
#
# This work cannot claim causal proof that a refresh causes traffic growth, and it cannot predict or explain Google's ranking algorithm. The results will show associations and opportunities based on the available data, not confirmed causes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
